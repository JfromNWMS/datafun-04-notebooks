# %% [markdown]
# # Jordan Notebook - Demo of Cell Creation
#
# - Author: [Jordan](https://github.com/JfromNWMS/)
# - Repository: [datafun-04-notebooks](https://github.com/JfromNWMS/datafun-04-notebooks)

# %% [markdown]
# ### Section 1. Imports

# %%
from numpy.random import normal
from pingouin import qqplot
import matplotlib.pyplot as plt

# %% [markdown]
# ### Section 2. Demo Visualization

# %%
data = normal(5,10,100)

qq_with_confidence = qqplot(data, dist='norm', confidence=0.95)
plt.title("Quantile-Quantile Plot")
plt.show()
